# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Fetch dataset 
mushrooms = pd.read_csv("mushrooms.csv")

# https://stackoverflow.com/questions/75997811/how-to-get-rid-of-error-could-not-convert-string-to-float
mushrooms = pd.get_dummies(mushrooms)

y = mushrooms['class_p']  
X = mushrooms[[i for i in mushrooms.columns if i not in ['class_e', 'class_p']]]
  
# https://www.geeksforgeeks.org/machine-learning/sklearn-perceptron/
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = Sequential()

model.add(Dense(128, activation='relu', input_shape=(X.shape[1],)))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# /home/phantruo/.local/lib/python3.12/site-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9655 - loss: 0.1190 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 2/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 7.0690e-04
# Epoch 3/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 2.5395e-04 - val_accuracy: 1.0000 - val_loss: 4.1063e-04
# Epoch 4/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.0831e-04 - val_accuracy: 1.0000 - val_loss: 1.5884e-04
# Epoch 5/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.5193e-05 - val_accuracy: 1.0000 - val_loss: 1.0714e-04
# Epoch 6/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.3455e-05 - val_accuracy: 1.0000 - val_loss: 7.7498e-05
# Epoch 7/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.1548e-05 - val_accuracy: 1.0000 - val_loss: 6.6987e-05
# Epoch 8/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.5488e-05 - val_accuracy: 1.0000 - val_loss: 5.0877e-05
# Epoch 9/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.0958e-05 - val_accuracy: 1.0000 - val_loss: 3.9892e-05
# Epoch 10/10
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 8.3034e-06 - val_accuracy: 1.0000 - val_loss: 3.8659e-05

# %%
y_pred = model.predict(X_test)

y_pred = (y_pred > 0.5).astype(int)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred, pos_label=1))
print("Recall:", recall_score(y_test, y_pred, pos_label=1))
print("F1 Score:", f1_score(y_test, y_pred, pos_label=1))
# Out:
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
